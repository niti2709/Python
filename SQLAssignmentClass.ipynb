# %%
'''1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
2 . create a database called as cardataset
3 . create a table called as car with a column name given in dataset description
4 . Dump all the data into car table 
5 . try to check weather all the data is aviable inside your table or not 
6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value 
7 . Try to filter a record where col 3 value will be 4 .
8.  Try to update a col 3 value with 8 whereever you have value equal to 2 
9 . try to delete table 
10 .   Try to delete database'''
# Out:
# '1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation\n2 . create a database called as cardataset\n3 . create a table called as car with a column name given in dataset description\n4 . Dump all the data into car table \n5 . try to check weather all the data is aviable inside your table or not \n6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value \n7 . Try to filter a record where col 3 value will be 4 .\n8.  Try to update a col 3 value with 8 whereever you have value equal to 2 \n9 . try to delete table \n10 .   Try to delete database'

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',passwd="mysql")

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
'''1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation'''
# Out:
# '1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation'

# %%
file =  open("car.names",'r')

# %%
'''2 . create a database called as cardataset'''
# Out:
# '2 . create a database called as cardataset'

# %%
cursor.execute("create database cardataset")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Can't create database 'cardataset'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17388/2144735912.py in <module>
# ----> 1 cursor.execute("create database cardataset")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %%
'''3 . create a table called as car with a column name given in dataset description'''
# Out:
# '3 . create a table called as car with a column name given in dataset description'

# %%
cursor.execute('create table cardataset.car5(buying char(10), maint char(10), doors char(5), persons char(5), log_boot char(10), safety char(10), class_val char(10))')

# %%
'''4 . Dump all the data into car table '''
# Out:
# '4 . Dump all the data into car table '

# %%
import csv
try:
    with open('car_data.csv','r') as f:
        car_data=csv.reader(f,delimiter=',')
        for i in car_data:
            data=((i[0]),(i[1]),(i[2]),(i[3]),(i[4]),(i[5]),(i[6]))
            query="""insert into cardataset.car5 (buying,maint,doors,persons,log_boot,safety,class_val) values (%s, %s, %s, %s, %s, %s, %s)"""
        #query="""insert into cardataset.car5 (buying,maint,doors,persons,log_boot,safety,class_val) values({i{0]},{}
            cursor.execute(query,data)
except mysql.connector.Error as e:
    print("Failed to insert into MySQL table {}".format(error))
#finally:
 #   mydb.commit()
  #  if mydb.is_connected():
   #         cursor.close()
    #        mydb.close()
     #       print("MySQL connection is closed")

# %%
'''5 . try to check weather all the data is aviable inside your table or not'''
# Out:
# '5 . try to check weather all the data is aviable inside your table or not'

# %%
import pandas as pd

# %%
pd.read_sql("select * from cardataset.car5",mydb)
# Out:
#      buying  maint  doors persons log_boot safety class_val
# 0     vhigh   high      2       2    small    low     unacc
# 1     vhigh  vhigh      2       2    small    low     unacc
# 2     vhigh  vhigh      2       2    small    med     unacc
# 3     vhigh  vhigh      2       2    small   high     unacc
# 4     vhigh  vhigh      2       2      med    low     unacc
# ...     ...    ...    ...     ...      ...    ...       ...
# 3452    low    low  5more    more      med    med      good
# 3453    low    low  5more    more      med   high     vgood
# 3454    low    low  5more    more      big    low     unacc
# 3455    low    low  5more    more      big    med      good
# 3456    low    low  5more    more      big   high     vgood
#
# [3457 rows x 7 columns]

# %%
cursor.execute('select * from cardataset.car5')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'high', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
# ...

# %%
'''6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value '''
# Out:
# '6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value '

# %%
q="""select buying,count(*) from cardataset.car5 group by buying"""

# %%
cursor.execute(q)

# %%
cursor.fetchall()
# Out:
# [('vhigh', 865), ('high', 864), ('med', 864), ('low', 864)]

# %%
'''7 . Try to filter a record where col 3 value will be 4 .'''
# Out:
# '7 . Try to filter a record where col 3 value will be 4 .'

# %%
pd.read_sql("select * from cardataset.car5 where doors=4",mydb)
# Out:
#     buying  maint doors persons log_boot safety class_val
# 0    vhigh  vhigh     4       2    small    low     unacc
# 1    vhigh  vhigh     4       2    small    med     unacc
# 2    vhigh  vhigh     4       2    small   high     unacc
# 3    vhigh  vhigh     4       2      med    low     unacc
# 4    vhigh  vhigh     4       2      med    med     unacc
# ..     ...    ...   ...     ...      ...    ...       ...
# 859    low    low     4    more      med    med      good
# 860    low    low     4    more      med   high     vgood
# 861    low    low     4    more      big    low     unacc
# 862    low    low     4    more      big    med      good
# 863    low    low     4    more      big   high     vgood
#
# [864 rows x 7 columns]

# %%
'''8.  Try to update a col 3 value with 8 whereever you have value equal to 2 '''
# Out:
# '8.  Try to update a col 3 value with 8 whereever you have value equal to 2 '

# %%
cursor.execute('update cardataset.car5 set doors=8 where doors=2')

# %%
pd.read_sql("select * from cardataset.car5 where doors=2",mydb)
# Out:
# Empty DataFrame
# Columns: [buying, maint, doors, persons, log_boot, safety, class_val]
# Index: []

# %%
pd.read_sql("select * from cardataset.car5 where doors=8",mydb)
# Out:
#   buying maint doors persons log_boot safety class_val
# 0  vhigh  high     8       2    small    low     unacc

# %%
mydb.commit()

# %%
'''9 . try to delete table'''
# Out:
# '9 . try to delete table'

# %%
cursor.execute('drop table cardataset.car5')

# %%
mydb.commit()

# %%
pd.read_sql("select * from cardataset.car5 where doors=8",mydb)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'cardataset.car5' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ...

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
cursor.execute('drop database cardataset')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
mydb.commit()

# %%
cursor.close()
# Out:
# True

# %%
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17388/589454993.py in <module>
# ----> 1 cursor.fetchall()
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in fetchall(self)
#     505         """
#     506         self._check_executed()
# --> 507         if not self._cnx.unread_result:
#     508             return []
#     509
#
# AttributeError: 'NoneType' object has no attribute 'unread_result'

# %%
mydb.close()
